# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('imports-85.data')

# %%
df
# Out:
#        3    ?  alfa-romero     gas    std   two  convertible  rwd  front  \
# 0    3.0    ?  alfa-romero     gas    std   two  convertible  rwd  front
# 1    1.0    ?  alfa-romero     gas    std   two    hatchback  rwd  front
# 2    2.0  164         audi     gas    std  four        sedan  fwd  front
# 3    2.0  164         audi     gas    std  four        sedan  4wd  front
# 4    2.0    ?         audi     gas    std   two        sedan  fwd  front
# ..   ...  ...          ...     ...    ...   ...          ...  ...    ...
# 200 -1.0   95        volvo     gas    std  four        sedan  rwd  front
# 201 -1.0   95        volvo     gas  turbo  four        sedan  rwd  front
# 202 -1.0   95        volvo     gas    std  four        sedan  rwd  front
# 203 -1.0   95        volvo  diesel  turbo  four        sedan  rwd  front
# 204 -1.0   95        volvo     gas  turbo  four        sedan  rwd  front
#
#      88.60  ...    130  mpfi  3.47  2.68  9.00  111  5000    21    27  13495
# ...

# %%
df.dtypes
# Out:
# 3              float64
# ?               object
# alfa-romero     object
# gas             object
# std             object
# two             object
# convertible     object
# rwd             object
# front           object
# 88.60          float64
# 168.80         float64
# 64.10          float64
# 48.80          float64
# 2548            object
# dohc            object
# four            object
# 130            float64
# mpfi            object
# 3.47            object
# 2.68            object
# 9.00           float64
# 111             object
# 5000            object
# 21             float64
# 27             float64
# 13495           object
# dtype: object

# %%
df.describe()
# Out:
#                 3       88.60       168.80       64.10       48.80  \
# count  204.000000  205.000000   205.000000  205.000000  205.000000
# mean     0.823529   99.104878   200.055122   65.673171   53.594146
# std      1.239035    7.349848   372.183092    4.091492    3.281524
# min     -2.000000   86.600000   141.100000   16.000000   22.000000
# 25%      0.000000   94.500000   166.300000   64.000000   52.000000
# 50%      1.000000   97.000000   173.200000   65.500000   54.100000
# 75%      2.000000  102.400000   183.500000   66.900000   55.500000
# max      3.000000  160.000000  5500.000000   72.300000   59.800000
#
#               130        9.00          21          27
# count  203.000000  203.000000  203.000000  203.000000
# mean   126.871921   10.163645   25.285714   30.812808
# std     41.846766    3.984660    6.535292    6.887673
# min     61.000000    7.000000   13.000000   16.000000
# 25%     97.000000    8.600000   19.000000   25.000000
# ...

# %%
kde = df.plot.kde(title='Distance',grid=True)
kde.set_xlabel('Wheel Base')
kde.set_ylabel('Frequency')
kde.set_xlim(-20,200)
# Out:
# (-20.0, 200.0)
